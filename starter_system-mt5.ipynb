# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib
import os
import pytz

import MetaTrader5 as mt5

from datetime import datetime
from pathlib import Path
from scipy import stats

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %matplotlib inline

# %%
# mt5 directory
mt5dir = r"C:\Program Files\MetaTrader 5 IC Markets (SC) - 1"
# mt5dir = r"C:\Program Files\Pepperstone MetaTrader 5"
mt5loc = Path(mt5dir) / 'terminal64.exe'

# connect to MetaTrader 5
if not mt5.initialize(str(mt5loc)):
    print("initialize() failed")
    mt5.shutdown()
    
# request connection status and parameters
print(mt5.terminal_info())
# get data on MetaTrader 5 version
print(mt5.version())
# Out:
# TerminalInfo(community_account=False, community_connection=False, connected=True, dlls_allowed=True, trade_allowed=True, tradeapi_disabled=False, email_enabled=False, ftp_enabled=False, notifications_enabled=False, mqid=False, build=2982, maxbars=100000000, codepage=0, ping_last=254849, community_balance=0.0, retransmission=0.0, company='Raw Trading Ltd', name='MetaTrader 5 IC Markets (SC)', language='English', path='C:\\Program Files\\MetaTrader 5 IC Markets (SC) - 1', ...)
# (500, 2982, '23 Jun 2021')

# %%
# Get the symbols from IC Markets MT5, excluding equity stocks
symbols = mt5.symbols_get("*, !*.*")

product_columns = [
    'name',
    'description',
    'path',
    'currency_base',
    'currency_profit',
    'currency_margin',
    'bid',
    'ask',
    'spread',
#     'last',
    'trade_contract_size',
    'volume_min',
    'volume_max',
    'volume_step',
    'trade_tick_value',
    'trade_tick_size',
    'margin_initial',
#     'margin_maintenance',
    'swap_long',
    'swap_short'
]


product_df = pd.DataFrame(columns=product_columns)

for symbol in symbols:
    product_df = product_df.append(
        pd.Series(
            [
                symbol.name,
                symbol.description,
                symbol.path,
                symbol.currency_base,
                symbol.currency_profit,
                symbol.currency_margin,
                symbol.bid,
                symbol.ask,
                symbol.ask - symbol.bid,
#                 symbol.last,
                symbol.trade_contract_size,
                symbol.volume_min,
                symbol.volume_max,
                symbol.volume_step,
                symbol.trade_tick_value,
                symbol.trade_tick_size,
                symbol.margin_initial,
#                 symbol.margin_maintenance,
                symbol.swap_long,
                symbol.swap_short
            ],
            index=product_columns
        ),
        ignore_index=True
    )

product_df
# Out:
#           name                                 description  \
# 0       EURUSD                           Euro vs US Dollar
# 1       GBPUSD            Great Britain Pound vs US Dollar
# 2       USDCHF                    US Dollar vs Swiss Franc
# 3       USDJPY                   US Dollar vs Japanese Yen
# 4       USDCAD                US Dollar vs Canadian Dollar
# ..         ...                                         ...
# 132  EURBBL_U1                Euro Bobl - September 21 CFD
# 133  EURBND_U1                Euro Bund - September 21 CFD
# 134  EURSCA_U1              Euro Schatz - September 21 CFD
# 135  ITB10Y_U1   Euro BTP Italian 10 YR - September 21 CFD
# 136   Sbean_Q1                     Soybean - August 21 CFD
#
#                            path currency_base currency_profit currency_margin  \
# 0           Forex\Majors\EURUSD           EUR             USD             EUR
# 1           Forex\Majors\GBPUSD           GBP             USD             GBP
# 2           Forex\Majors\USDCHF           USD             CHF             USD
# 3           Forex\Majors\USDJPY           USD             JPY             USD
# 4           Forex\Majors\USDCAD           USD             CAD             USD
# ..                          ...           ...             ...             ...
# 132        Bonds CFDs\EURBBL_U1           USD             EUR             EUR
# 133        Bonds CFDs\EURBND_U1           USD             EUR             EUR
# 134        Bonds CFDs\EURSCA_U1           USD             EUR             EUR
# 135        Bonds CFDs\ITB10Y_U1           USD             EUR             EUR
# 136  Commodities\Softs\Sbean_Q1           USD             USD             USD
#
#             bid         ask   spread  trade_contract_size  volume_min  \
# 0       1.18260     1.18260  0.00000             100000.0        0.01
# 1       1.38262     1.38267  0.00005             100000.0        0.01
# 2       0.91514     0.91517  0.00003             100000.0        0.01
# 3     109.90700   109.90900  0.00200             100000.0        0.01
# 4       1.25381     1.25385  0.00004             100000.0        0.01
# ..          ...         ...      ...                  ...         ...
# 132   134.64000   134.65000  0.01000                100.0        1.00
# 133   174.56000   174.57000  0.01000                100.0        1.00
# 134   112.18000   112.19000  0.01000                100.0        1.00
# 135   152.95000   152.97000  0.02000                100.0        1.00
# 136  1452.57000  1453.92000  1.35000                  4.0        1.00
#
#      volume_max  volume_step  trade_tick_value  trade_tick_size  \
# 0         200.0         0.01          1.000000          0.00001
# 1         200.0         0.01          1.000000          0.00001
# 2         200.0         0.01          1.092693          0.00001
# 3         200.0         0.01          0.909844          0.00100
# 4         200.0         0.01          0.797544          0.00001
# ..          ...          ...               ...              ...
# 132       100.0         1.00          1.182600          0.01000
# 133       100.0         1.00          1.182600          0.01000
# 134       100.0         1.00          1.182600          0.01000
# 135       100.0         1.00          1.182600          0.01000
# 136       200.0         1.00          0.040000          0.01000
#
#      margin_initial  swap_long  swap_short
# 0          100000.0      -5.23       -0.47
# 1          100000.0      -3.44       -2.73
# 2          100000.0       0.11       -4.87
# 3          100000.0      -1.72       -3.94
# 4          100000.0      -2.95       -2.97
# ..              ...        ...         ...
# 132             0.0       0.00        0.00
# 133             0.0       0.00        0.00
# 134             0.0       0.00        0.00
# 135             0.0       0.00        0.00
# 136             0.0       0.00        0.00
#
# [137 rows x 18 columns]

# %%
product_df.to_clipboard()

# %%
product_df[product_df['volume_min'] != product_df['volume_step']]
# Out:
#        name         description           path currency_base currency_profit  \
# 89   XRPUSD    Ripple US Dollar  Crypto\XRPUSD           USD             USD
# 90   EOSUSD       EOS US Dollar  Crypto\EOSUSD           USD             USD
# 91   EMCUSD  Emercoin US Dollar  Crypto\EMCUSD           USD             USD
# 92   NMCUSD  NameCoin US Dollar  Crypto\NMCUSD           USD             USD
# 93   PPCUSD  PeerCoin US Dollar  Crypto\PPCUSD           USD             USD
# 129  ADAUSD       Cardano (USD)  Crypto\ADAUSD           USD             USD
#
#     currency_margin     bid     ask  spread  trade_contract_size  volume_min  \
# 89              USD  0.6084  0.6255  0.0171                  1.0         1.0
# 90              USD  3.8070  3.8460  0.0390                  1.0         1.0
# 91              USD  0.0001  0.1778  0.1777                  1.0         1.0
# 92              USD  0.0050  7.9000  7.8950                  1.0         1.0
# 93              USD  0.8450  7.1880  6.3430                  1.0         1.0
# 129             USD  0.0000  0.0000  0.0000                  1.0         1.0
#
#      volume_max  volume_step  trade_tick_value  trade_tick_size  \
# 89        100.0         0.01           0.00010          0.00010
# 90        100.0         0.01           0.00010          0.00010
# 91        100.0         0.01           0.00010          0.00010
# 92        100.0         0.01           0.00100          0.00100
# 93        100.0         0.01           0.00100          0.00100
# 129       100.0         0.01           0.00001          0.00001
#
#      margin_initial  swap_long  swap_short
# 89              0.0      -20.0       -20.0
# 90              0.0      -20.0       -20.0
# 91              0.0      -20.0       -20.0
# 92              0.0      -20.0       -20.0
# 93              0.0      -20.0       -20.0
# 129             0.0      -22.5       -15.0

# %%
product_df['name']
# Out:
# 0         EURUSD
# 1         GBPUSD
# 2         USDCHF
# 3         USDJPY
# 4         USDCAD
#          ...
# 132    EURBBL_U1
# 133    EURBND_U1
# 134    EURSCA_U1
# 135    ITB10Y_U1
# 136     Sbean_Q1
# Name: name, Length: 137, dtype: object

# %%
product_df['currency_profit'].unique()
# Out:
# array(['USD', 'CHF', 'JPY', 'CAD', 'NZD', 'GBP', 'AUD', 'SGD', 'DKK',
#        'HKD', 'NOK', 'PLN', 'SEK', 'TRY', 'ZAR', 'CNH', 'CZK', 'HUF',
#        'MXN', 'RUB', 'THB', 'EUR'], dtype=object)

# %%
product_df.to_clipboard()

# %% [markdown]
# # Download OHLC Data

# %%
"""
Create a dictionary where the key is the ticker
and the value is a pandas dataframe of the OHLC time series
"""
timeframe = mt5.TIMEFRAME_D1
lookback = 10000000

product_ohlc = {}

for ticker in product_df['name']:
    product_ohlc[ticker] = pd.DataFrame(mt5.copy_rates_from_pos(ticker, timeframe, 0, lookback))
    try:
        product_ohlc[ticker]['time'] = pd.to_datetime(product_ohlc[ticker]['time'], unit='s')
        product_ohlc[ticker].set_index('time', inplace=True)
    except KeyError:
        print(f'KeyError on {ticker}')

product_ohlc['EURUSD']
# Out:
# KeyError on EURUSD
# KeyError on GBPUSD
# KeyError on USDCHF
# KeyError on USDJPY
# KeyError on USDCAD
# KeyError on AUDUSD
# KeyError on AUDNZD
# KeyError on AUDCAD
# KeyError on AUDCHF
# KeyError on AUDJPY
# KeyError on CHFJPY
# KeyError on EURGBP
# KeyError on EURAUD
# KeyError on EURCHF
# KeyError on EURJPY
# KeyError on EURNZD
# KeyError on EURCAD
# KeyError on GBPCHF
# KeyError on GBPJPY
# KeyError on CADCHF
# KeyError on CADJPY
# KeyError on GBPAUD
# KeyError on GBPCAD
# KeyError on GBPNZD
# KeyError on NZDCAD
# KeyError on NZDCHF
# KeyError on NZDJPY
# KeyError on NZDUSD
# KeyError on USDSGD
# KeyError on AUDSGD
# KeyError on CHFSGD
# KeyError on EURDKK
# KeyError on EURHKD
# KeyError on EURNOK
# KeyError on EURPLN
# KeyError on EURSEK
# KeyError on EURSGD
# KeyError on EURTRY
# KeyError on EURZAR
# KeyError on GBPDKK
# KeyError on GBPNOK
# KeyError on GBPSEK
# KeyError on GBPSGD
# KeyError on GBPTRY
# KeyError on NOKJPY
# KeyError on NOKSEK
# KeyError on SEKJPY
# KeyError on SGDJPY
# KeyError on USDCNH
# KeyError on USDCZK
# KeyError on USDDKK
# KeyError on USDHKD
# KeyError on USDHUF
# KeyError on USDMXN
# KeyError on USDNOK
# KeyError on USDPLN
# KeyError on USDRUB
# KeyError on USDSEK
# KeyError on USDTHB
# KeyError on USDTRY
# KeyError on USDZAR
# KeyError on AUS200
# KeyError on CHINA50
# KeyError on DE30
# KeyError on ES35
# KeyError on STOXX50
# KeyError on F40
# KeyError on HK50
# KeyError on IT40
# KeyError on JP225
# KeyError on UK100
# KeyError on US2000
# KeyError on US30
# KeyError on US500
# KeyError on USTEC
# KeyError on XAGEUR
# KeyError on XAGUSD
# KeyError on XAUEUR
# KeyError on XAUUSD
# KeyError on XPDUSD
# KeyError on XPTUSD
# KeyError on XBRUSD
# KeyError on XNGUSD
# KeyError on XTIUSD
# KeyError on BTCUSD
# KeyError on BCHUSD
# KeyError on DSHUSD
# KeyError on ETHUSD
# KeyError on LTCUSD
# KeyError on XRPUSD
# KeyError on EOSUSD
# KeyError on EMCUSD
# KeyError on NMCUSD
# KeyError on PPCUSD
# KeyError on XAUAUD
# KeyError on CA60
# KeyError on NETH25
# KeyError on SE30
# KeyError on SWI20
# KeyError on CHINAH
# KeyError on SA40
# KeyError on NOR25
# KeyError on TecDE30
# KeyError on MidDE60
# KeyError on Wheat_U1
# KeyError on Corn_U1
# KeyError on Sugar_V1
# KeyError on DXY_U1
# KeyError on EURBOBL_M1
# KeyError on EURBOBL_U1
# KeyError on EURBUND_M1
# KeyError on EURBUND_U1
# KeyError on EURSCHA_M1
# KeyError on EURSCHA_U1
# KeyError on UST05Y_U1
# KeyError on UST10Y_U1
# KeyError on UST30Y_U1
# KeyError on UKGB_M1
# KeyError on UKGB_U1
# KeyError on JGB10Y_M1
# KeyError on ITBTP10Y_M1
# KeyError on ITBTP10Y_U1
# KeyError on VIX_N1
# KeyError on WTI_Q1
# KeyError on OJ_U1
# KeyError on BRENT_U1
# KeyError on Cocoa_U1
# KeyError on Coffee_U1
# KeyError on Cotton_Z1
# KeyError on ADAUSD
# KeyError on TRXUSD
# KeyError on XMRUSD
# KeyError on EURBBL_U1
# KeyError on EURBND_U1
# KeyError on EURSCA_U1
# KeyError on ITB10Y_U1
# KeyError on Sbean_Q1
# Empty DataFrame
# Columns: []
# Index: []

# %%
for ticker, ohlc in product_ohlc.items():
    ohlc.to_csv(f'data/{ticker}.csv')

# %% [markdown]
# # Calculate Volatility

# %%
def volatility(ts, lookback=24):
    """
    Input:  Price time series, Look back period
    Output: Standard deviation of the percent change
    """
    return ts.pct_change().rolling(lookback).std().iloc[-1]

    # alternative caltulation using ewma
#     return ts.pct_change().ewm(span=lookback).std().iloc[-1]

# %%
# Create an empty DataFrame to store score

ins_risk_columns = [
    'ticker',
    'last_date',
    'ins_risk'
]

ins_risk_table = pd.DataFrame(columns=ins_risk_columns)

# How many (series) candles back for std dev calculation?
vola_window = 24

# Loop the dictionary and calculate the momentum_score, then append it to pandas
for ticker, ohlc in product_ohlc.items():
    try:
        ins_risk = volatility(ohlc['close'], vola_window) * 16
        last_date = ohlc.index[-1]
        ins_risk_table = ins_risk_table.append(
            pd.Series(
                [
                    ticker,
                    last_date,
                    ins_risk
                ],
                index=ins_risk_columns
            ),
            ignore_index=True
        )
    except KeyError:
        print(f'KeyError on {ticker}')

ins_risk_table
# Out:
# KeyError on ADAUSD
# KeyError on TRXUSD
# KeyError on XMRUSD
#         ticker  last_date  ins_risk
# 0       EURUSD 2021-07-02  0.056902
# 1       GBPUSD 2021-07-02  0.069191
# 2       USDCHF 2021-07-02  0.069109
# 3       USDJPY 2021-07-02  0.054362
# 4       USDCAD 2021-07-02  0.075771
# ..         ...        ...       ...
# 130  EURBBL_U1 2021-07-02       NaN
# 131  EURBND_U1 2021-07-02       NaN
# 132  EURSCA_U1 2021-07-02       NaN
# 133  ITB10Y_U1 2021-07-02       NaN
# 134   Sbean_Q1 2021-07-02       NaN
#
# [135 rows x 3 columns]

# %%
ins_risk_table.to_clipboard()

# %%
product_df['ins_risk'] = ins_risk_table['ins_risk']

# %%
product_df['tick_value_min'] = product_df['trade_contract_size'] * product_df['volume_min'] * product_df['trade_tick_value'] * product_df['trade_tick_size']
product_df['ins_risk_curr'] = product_df['bid'] * product_df['tick_value_min'] * product_df['ins_risk'] * product_df['trade_contract_size']
product_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\envs\algotrade\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\miniconda3\envs\algotrade\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\miniconda3\envs\algotrade\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ins_risk'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-fa7a31b36a7e> in <module>
#       1 product_df['tick_value_min'] = product_df['trade_contract_size'] * product_df['volume_min'] * product_df['trade_tick_value'] * product_df['trade_tick_size']
# ----> 2 product_df['ins_risk_curr'] = product_df['bid'] * product_df['tick_value_min'] * product_df['ins_risk'] * product_df['trade_contract_size']
#       3 product_df
#
# ~\miniconda3\envs\algotrade\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~\miniconda3\envs\algotrade\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'ins_risk'
